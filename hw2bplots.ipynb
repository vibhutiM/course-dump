# %%
# %matplotlib inline
# Out:
# /Users/abc/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
testacc=[57.993851, 78.996925, 78.255188, 78.578017]
testacc1=[58.366641045349724,78.897002305918519,78.097617217524984,70.053804765564948,79.515757109915455,0]
testacc2=[50.561106840891611,56.20292083013068,53.647194465795543,57.221368178324369,57.99385088393543]

# %%
plt.plot([1,3,5,7], testacc)
plt.axis([0, 8, 54, 80])
plt.ylabel('Test Accuracy(%)')
plt.xlabel('no. of hidden layers')
plt.show()

# %%
plt.plot([1,2,3,4,5,6], testacc1)
plt.axis([0, 8, 58, 80])
plt.ylabel('Test Accuracy(%)')
plt.xlabel('no. of hidden layers')
plt.show()

# %%
plt.plot([50,100,200,400,500], testacc2)
plt.axis([0, 600, 47, 60])
plt.ylabel('Test Accuracy(%)')
plt.xlabel('no. of neurons in hidden layers')
plt.show()
